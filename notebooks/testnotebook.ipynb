# %% [markdown]
# First of all, test hooks for matplotlib magic.

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
plt.plot([1, 2], [3, 4])
plt.legend()
plt.show()

# %% [markdown]
# Now, we can define functions that will be checked in isolation.

# %%
def foo():
    return 42

# %%
def bar(n):
    return n**2

# %%
def zoo(n):
    return foo()
